# %% [markdown]
# # YAHOO電影爬蟲練習
# ## 練習爬取電影放映資訊。必須逐步獲取電影的代號、放映地區、放映日期後，再送出查詢給伺服器。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先搜尋全部的電影代號(ID)資訊

# %%
# 查看目前上映那些電影，並擷取出其ID資訊
url = 'https://movies.yahoo.com.tw/'
resp = requests.get(url)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
#print(soup)
html = soup.find("select", attrs={'name':'movie_id'})
print(html)
movie_item = html.find_all("option", attrs={'data-name':re.compile('.*')})
print(movie_item)
for p in movie_item:
    print("Movie: %s, ID: %s" % (p["data-name"], p["value"]))
# Out:
# <select class="movie_name" id="sbox_mid" name="movie_id">
# <option value="">請選擇片名</option>
# <option data-name="導演先生的完美假期" value="10545">導演先生的完美假期</option>
# <option data-name="大地蜜語" value="10513">大地蜜語</option>
# <option data-name="狂飆一夢" value="10506">狂飆一夢</option>
# <option data-name="親愛的莎瑪" value="10491">親愛的莎瑪</option>
# <option data-name="大畫特務" value="10478">大畫特務</option>
# <option data-name="戰慄糖果屋" value="10472">戰慄糖果屋</option>
# <option data-name="失戀殺人：三角禁戀" value="10465">失戀殺人：三角禁戀</option>
# <option data-name="明明會說話" value="10440">明明會說話</option>
# <option data-name="艾瑪" value="10396">艾瑪</option>
# <option data-name="罪樂園" value="10349">罪樂園</option>
# <option data-name="寄生上流：黑白版" value="10527">寄生上流：黑白版</option>
# <option data-name="千日千夜" value="10490">千日千夜</option>
# <option data-name="咒怨2 電影版" value="10464">咒怨2 電影版</option>
# <option data-name="鳴鳥不飛：烏雲密布" value="10458">鳴鳥不飛：烏雲密布</option>
# <option data-name="哥布林殺手 劇場版" value="10438">哥布林殺手 劇場版</option>
# <option data-name="女鬼橋" value="10437">女鬼橋</option>
# <option data-name="怨咒" value="10421">怨咒</option>
# <option data-name="娘娘腔日記" value="10401">娘娘腔日記</option>
# <option data-name="汪星人的奇幻漂流" value="10388">汪星人的奇幻漂流</option>
# <option data-name="極地守護犬" value="10383">極地守護犬</option>
# <option data-name="叔．叔" value="10371">叔．叔</option>
# <option data-name="隱形人" value="10359">隱形人</option>
# <option data-name="失路人" value="10498">失路人</option>
# <option data-name="電影音效傳奇：好萊塢之聲" value="10484">電影音效傳奇：好萊塢之聲</option>
# <option data-name="悲慘世界" value="10479">悲慘世界</option>
# <option data-name="吹哨奇案" value="10475">吹哨奇案</option>
# <option data-name="閃閃小超人電影版" value="10474">閃閃小超人電影版</option>
# <option data-name="少年阿罕默德" value="10468">少年阿罕默德</option>
# <option data-name="咒怨 電影版" value="10463">咒怨 電影版</option>
# <option data-name="陰櫥" value="10457">陰櫥</option>
# <option data-name="絕命大平台" value="10447">絕命大平台</option>
# <option data-name="李察朱威爾事件" value="10368">李察朱威爾事件</option>
# <option data-name="音速小子" value="9246">音速小子</option>
# <option data-name="你好．愛．再見" value="10501">你好．愛．再見</option>
# <option data-name="逃出夢幻島" value="10485">逃出夢幻島</option>
# <option data-name="雨天．紐約" value="10476">雨天．紐約</option>
# <option data-name="失控少年兵團" value="10456">失控少年兵團</option>
# <option data-name="超＂人＂氣動物園" value="10445">超＂人＂氣動物園</option>
# <option data-name="就愛斷捨離" value="10436">就愛斷捨離</option>
# <option data-name="愛情人形" value="10394">愛情人形</option>
# <option data-name="蜜蜂與遠雷" value="10419">蜜蜂與遠雷</option>
# <option data-name="電影版 輝夜姬想讓人告白～天才們的戀愛頭腦戰～" value="10405">電影版 輝夜姬想讓人告白～天才們的戀愛頭腦戰～</option>
# <option data-name="古曼童" value="10399">古曼童</option>
# <option data-name="猛禽小隊：小丑女大解放" value="10268">猛禽小隊：小丑女大解放</option>
# <option data-name="紅鞋公主與七矮人" value="10417">紅鞋公主與七矮人</option>
# <option data-name="1917" value="10189">1917</option>
# <option data-name="你的情歌" value="10407">你的情歌</option>
# <option data-name="杜立德" value="10316">杜立德</option>
# <option data-name="她們" value="10202">她們</option>
# <option data-name="變身特務" value="9008">變身特務</option>
# <option data-name="然後我們跳了舞" value="10451">然後我們跳了舞</option>
# <option data-name="巧虎電影：英雄遊樂園" value="10429">巧虎電影：英雄遊樂園</option>
# <option data-name="青春催落去" value="10404">青春催落去</option>
# <option data-name="絕地戰警FOR LIFE" value="10242">絕地戰警FOR LIFE</option>
# <option data-name="星星知我心" value="10409">星星知我心</option>
# <option data-name="逃出天堂島" value="10384">逃出天堂島</option>
# <option data-name="魯邦三世 The First" value="10355">魯邦三世 The First</option>
# <option data-name="別告訴她" value="10382">別告訴她</option>
# <option data-name="真愛裁會贏" value="10362">真愛裁會贏</option>
# <option data-name="潛艦追緝" value="10333">潛艦追緝</option>
# <option data-name="霹靂嬌娃" value="10124">霹靂嬌娃</option>
# <option data-name="CATS貓" value="10166">CATS貓</option>
# <option data-name="STAR WARS : 天行者的崛起" value="10225">STAR WARS : 天行者的崛起</option>
# <option data-name="復仇母親" value="10392">復仇母親</option>
# <option data-name="8級警戒" value="10323">8級警戒</option>
# <option data-name="黑色聖誕節" value="10291">黑色聖誕節</option>
# <option data-name="去年聖誕節" value="10256">去年聖誕節</option>
# <option data-name="野蠻遊戲：全面晉級" value="10134">野蠻遊戲：全面晉級</option>
# <option data-name="寂寞診療室" value="10282">寂寞診療室</option>
# <option data-name="賽道狂人" value="10097">賽道狂人</option>
# <option data-name="冰雪奇緣2" value="9597">冰雪奇緣2</option>
# <option data-name="萬萬沒想到" value="10281">萬萬沒想到</option>
# <option data-name="救火奶爸" value="10164">救火奶爸</option>
# <option data-name="決戰中途島" value="10130">決戰中途島</option>
# <option data-name="魔鬼終結者：黑暗宿命" value="10067">魔鬼終結者：黑暗宿命</option>
# <option data-name="絕鯊47：猛鯊出籠" value="10214">絕鯊47：猛鯊出籠</option>
# <option data-name="貓咪知道但是貓咪不說" value="10203">貓咪知道但是貓咪不說</option>
# <option data-name="天氣之子" value="10091">天氣之子</option>
# <option data-name="寄生上流" value="10020">寄生上流</option>
# <option data-name="一首搖滾上月球" value="4887">一首搖滾上月球</option>
# <option data-name="錢不夠用2" value="3026">錢不夠用2</option>
# </select>
# [<option data-name="導演先生的完美假期" value="10545">導演先生的完美假期</option>, <option data-name="大地蜜語" value="10513">大地蜜語</option>, <option data-name="狂飆一夢" value="10506">狂飆一夢</option>, <option data-name="親愛的莎瑪" value="10491">親愛的莎瑪</option>, <option data-name="大畫特務" value="10478">大畫特務</option>, <option data-name="戰慄糖果屋" value="10472">戰慄糖果屋</option>, <option data-name="失戀殺人：三角禁戀" value="10465">失戀殺人：三角禁戀</option>, <option data-name="明明會說話" value="10440">明明會說話</option>, <option data-name="艾瑪" value="10396">艾瑪</option>, <option data-name="罪樂園" value="10349">罪樂園</option>, <option data-name="寄生上流：黑白版" value="10527">寄生上流：黑白版</option>, <option data-name="千日千夜" value="10490">千日千夜</option>, <option data-name="咒怨2 電影版" value="10464">咒怨2 電影版</option>, <option data-name="鳴鳥不飛：烏雲密布" value="10458">鳴鳥不飛：烏雲密布</option>, <option data-name="哥布林殺手 劇場版" value="10438">哥布林殺手 劇場版</option>, <option data-name="女鬼橋" value="10437">女鬼橋</option>, <option data-name="怨咒" value="10421">怨咒</option>, <option data-name="娘娘腔日記" value="10401">娘娘腔日記</option>, <option data-name="汪星人的奇幻漂流" value="10388">汪星人的奇幻漂流</option>, <option data-name="極地守護犬" value="10383">極地守護犬</option>, <option data-name="叔．叔" value="10371">叔．叔</option>, <option data-name="隱形人" value="10359">隱形人</option>, <option data-name="失路人" value="10498">失路人</option>, <option data-name="電影音效傳奇：好萊塢之聲" value="10484">電影音效傳奇：好萊塢之聲</option>, <option data-name="悲慘世界" value="10479">悲慘世界</option>, <option data-name="吹哨奇案" value="10475">吹哨奇案</option>, <option data-name="閃閃小超人電影版" value="10474">閃閃小超人電影版</option>, <option data-name="少年阿罕默德" value="10468">少年阿罕默德</option>, <option data-name="咒怨 電影版" value="10463">咒怨 電影版</option>, <option data-name="陰櫥" value="10457">陰櫥</option>, <option data-name="絕命大平台" value="10447">絕命大平台</option>, <option data-name="李察朱威爾事件" value="10368">李察朱威爾事件</option>, <option data-name="音速小子" value="9246">音速小子</option>, <option data-name="你好．愛．再見" value="10501">你好．愛．再見</option>, <option data-name="逃出夢幻島" value="10485">逃出夢幻島</option>, <option data-name="雨天．紐約" value="10476">雨天．紐約</option>, <option data-name="失控少年兵團" value="10456">失控少年兵團</option>, <option data-name="超＂人＂氣動物園" value="10445">超＂人＂氣動物園</option>, <option data-name="就愛斷捨離" value="10436">就愛斷捨離</option>, <option data-name="愛情人形" value="10394">愛情人形</option>, <option data-name="蜜蜂與遠雷" value="10419">蜜蜂與遠雷</option>, <option data-name="電影版 輝夜姬想讓人告白～天才們的戀愛頭腦戰～" value="10405">電影版 輝夜姬想讓人告白～天才們的戀愛頭腦戰～</option>, <option data-name="古曼童" value="10399">古曼童</option>, <option data-name="猛禽小隊：小丑女大解放" value="10268">猛禽小隊：小丑女大解放</option>, <option data-name="紅鞋公主與七矮人" value="10417">紅鞋公主與七矮人</option>, <option data-name="1917" value="10189">1917</option>, <option data-name="你的情歌" value="10407">你的情歌</option>, <option data-name="杜立德" value="10316">杜立德</option>, <option data-name="她們" value="10202">她們</option>, <option data-name="變身特務" value="9008">變身特務</option>, <option data-name="然後我們跳了舞" value="10451">然後我們跳了舞</option>, <option data-name="巧虎電影：英雄遊樂園" value="10429">巧虎電影：英雄遊樂園</option>, <option data-name="青春催落去" value="10404">青春催落去</option>, <option data-name="絕地戰警FOR LIFE" value="10242">絕地戰警FOR LIFE</option>, <option data-name="星星知我心" value="10409">星星知我心</option>, <option data-name="逃出天堂島" value="10384">逃出天堂島</option>, <option data-name="魯邦三世 The First" value="10355">魯邦三世 The First</option>, <option data-name="別告訴她" value="10382">別告訴她</option>, <option data-name="真愛裁會贏" value="10362">真愛裁會贏</option>, <option data-name="潛艦追緝" value="10333">潛艦追緝</option>, <option data-name="霹靂嬌娃" value="10124">霹靂嬌娃</option>, <option data-name="CATS貓" value="10166">CATS貓</option>, <option data-name="STAR WARS : 天行者的崛起" value="10225">STAR WARS : 天行者的崛起</option>, <option data-name="復仇母親" value="10392">復仇母親</option>, <option data-name="8級警戒" value="10323">8級警戒</option>, <option data-name="黑色聖誕節" value="10291">黑色聖誕節</option>, <option data-name="去年聖誕節" value="10256">去年聖誕節</option>, <option data-name="野蠻遊戲：全面晉級" value="10134">野蠻遊戲：全面晉級</option>, <option data-name="寂寞診療室" value="10282">寂寞診療室</option>, ...
# Movie: 導演先生的完美假期, ID: 10545
# Movie: 大地蜜語, ID: 10513
# Movie: 狂飆一夢, ID: 10506
# Movie: 親愛的莎瑪, ID: 10491
# Movie: 大畫特務, ID: 10478
# Movie: 戰慄糖果屋, ID: 10472
# Movie: 失戀殺人：三角禁戀, ID: 10465
# Movie: 明明會說話, ID: 10440
# Movie: 艾瑪, ID: 10396
# Movie: 罪樂園, ID: 10349
# Movie: 寄生上流：黑白版, ID: 10527
# Movie: 千日千夜, ID: 10490
# Movie: 咒怨2 電影版, ID: 10464
# Movie: 鳴鳥不飛：烏雲密布, ID: 10458
# Movie: 哥布林殺手 劇場版, ID: 10438
# Movie: 女鬼橋, ID: 10437
# Movie: 怨咒, ID: 10421
# Movie: 娘娘腔日記, ID: 10401
# Movie: 汪星人的奇幻漂流, ID: 10388
# Movie: 極地守護犬, ID: 10383
# Movie: 叔．叔, ID: 10371
# Movie: 隱形人, ID: 10359
# Movie: 失路人, ID: 10498
# Movie: 電影音效傳奇：好萊塢之聲, ID: 10484
# Movie: 悲慘世界, ID: 10479
# Movie: 吹哨奇案, ID: 10475
# Movie: 閃閃小超人電影版, ID: 10474
# Movie: 少年阿罕默德, ID: 10468
# Movie: 咒怨 電影版, ID: 10463
# Movie: 陰櫥, ID: 10457
# Movie: 絕命大平台, ID: 10447
# Movie: 李察朱威爾事件, ID: 10368
# Movie: 音速小子, ID: 9246
# Movie: 你好．愛．再見, ID: 10501
# Movie: 逃出夢幻島, ID: 10485
# Movie: 雨天．紐約, ID: 10476
# Movie: 失控少年兵團, ID: 10456
# Movie: 超＂人＂氣動物園, ID: 10445
# Movie: 就愛斷捨離, ID: 10436
# Movie: 愛情人形, ID: 10394
# Movie: 蜜蜂與遠雷, ID: 10419
# Movie: 電影版 輝夜姬想讓人告白～天才們的戀愛頭腦戰～, ID: 10405
# Movie: 古曼童, ID: 10399
# Movie: 猛禽小隊：小丑女大解放, ID: 10268
# Movie: 紅鞋公主與七矮人, ID: 10417
# Movie: 1917, ID: 10189
# Movie: 你的情歌, ID: 10407
# Movie: 杜立德, ID: 10316
# Movie: 她們, ID: 10202
# Movie: 變身特務, ID: 9008
# Movie: 然後我們跳了舞, ID: 10451
# Movie: 巧虎電影：英雄遊樂園, ID: 10429
# Movie: 青春催落去, ID: 10404
# Movie: 絕地戰警FOR LIFE, ID: 10242
# Movie: 星星知我心, ID: 10409
# Movie: 逃出天堂島, ID: 10384
# Movie: 魯邦三世 The First, ID: 10355
# Movie: 別告訴她, ID: 10382
# Movie: 真愛裁會贏, ID: 10362
# Movie: 潛艦追緝, ID: 10333
# Movie: 霹靂嬌娃, ID: 10124
# Movie: CATS貓, ID: 10166
# Movie: STAR WARS : 天行者的崛起, ID: 10225
# Movie: 復仇母親, ID: 10392
# Movie: 8級警戒, ID: 10323
# Movie: 黑色聖誕節, ID: 10291
# Movie: 去年聖誕節, ID: 10256
# Movie: 野蠻遊戲：全面晉級, ID: 10134
# Movie: 寂寞診療室, ID: 10282
# Movie: 賽道狂人, ID: 10097
# Movie: 冰雪奇緣2, ID: 9597
# Movie: 萬萬沒想到, ID: 10281
# Movie: 救火奶爸, ID: 10164
# Movie: 決戰中途島, ID: 10130
# Movie: 魔鬼終結者：黑暗宿命, ID: 10067
# Movie: 絕鯊47：猛鯊出籠, ID: 10214
# Movie: 貓咪知道但是貓咪不說, ID: 10203
# Movie: 天氣之子, ID: 10091
# Movie: 寄生上流, ID: 10020
# Movie: 一首搖滾上月球, ID: 4887
# Movie: 錢不夠用2, ID: 3026

# %% [markdown]
# ### 指定你有興趣的電影其ID，然後查詢其放映地區資訊。

# %%
# 參考前一個步驟中擷取到的ID資訊，並指定ID
movie_id = 10438

# %%
url = 'https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
payload = {'movie_id':str(movie_id)}

# 模擬一個header
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'path': '/api/v1/areas_by_movie_theater?movie_id=' + str(movie_id),
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
    
resp = requests.get(url, params=payload, headers=headers)
print(resp.json())  # 若有需要，列印出json原始碼

# 這裡回傳的格式是JSON格式的資料，要解析JSON擷取資料
for p in resp.json():
    print('放映地區: {0}, 代號(area_id): {1}'.format(p['title'], p['area_id']))
# Out:
# [{'area_id': 28, 'title': '台北市', 'priority': 150, 'ts_update': 1547519309}, {'area_id': 8, 'title': '新北市', 'priority': 145, 'ts_update': 1547194527}, {'area_id': 16, 'title': '桃園', 'priority': 140, 'ts_update': 1547452573}, {'area_id': 20, 'title': '新竹', 'priority': 135, 'ts_update': 1547452603}, {'area_id': 15, 'title': '苗栗', 'priority': 130, 'ts_update': 1547452620}, {'area_id': 2, 'title': '台中', 'priority': 125, 'ts_update': 1547507368}, {'area_id': 10, 'title': '台南', 'priority': 100, 'ts_update': 1547507403}, {'area_id': 17, 'title': '高雄', 'priority': 95, 'ts_update': 1547507403}, {'area_id': 23, 'title': '澎湖', 'priority': 65, 'ts_update': 1547507437}]
# 放映地區: 台北市, 代號(area_id): 28
# 放映地區: 新北市, 代號(area_id): 8
# 放映地區: 桃園, 代號(area_id): 16
# 放映地區: 新竹, 代號(area_id): 20
# 放映地區: 苗栗, 代號(area_id): 15
# 放映地區: 台中, 代號(area_id): 2
# 放映地區: 台南, 代號(area_id): 10
# 放映地區: 高雄, 代號(area_id): 17
# 放映地區: 澎湖, 代號(area_id): 23

# %% [markdown]
# ### 指定你想要觀看的放映地區，查詢有上映電影的場次日期

# %%
# 指定放映地區
area_id = 28

# %%
# 向網站發送請求
url = 'https://movies.yahoo.com.tw/movietime_result.html'
payload = {'movie_id':str(movie_id), 'area_id':str(area_id)}
resp = requests.get(url, params=payload)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
#print(soup)
movie_date = soup.find_all("label", attrs={'for':re.compile("date_[\d]")})

# 列印播放日期
for date in movie_date:
    print("%s %s" % (date.p.string, date.h3.string))
# Out:
# 三月 11
# 三月 12
# 三月 13
# 三月 14
# 三月 15

# %% [markdown]
# ### 最後指定觀看的日期，查詢並列印出放映的電影院、放映類型(數位、3D、IMAX 3D...)、放映時間等資訊。

# %%
# 選定要觀看的日期
date = "2020-03-11"

# %%
# 向網站發送請求，獲取上映的電影院及時間資訊
url = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
payload = {'movie_id':str(movie_id),
           'date':date,
           'area_id':str(area_id),
           'theater_id':'',
           'datetime':'',
           'movie_type_id':''}

resp = requests.get(url, params=payload)
#print(resp.json()['view'])  # 若有需要，列印出json原始碼

soup = BeautifulSoup(resp.json()['view'], 'lxml')
html = soup.find_all("ul", attrs={'data-theater_name':re.compile(".*")})
print(html)
# Out:
# [<ul class="area_time _c jq_area_time" data-theater_name="國賓影城(台北長春廣場)" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=29" data-theater_url="http://www.ambassador.com.tw/" id="theater_id_29">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=29">國賓影城(台北長春廣場)</a>
# <span>02-25155755</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '哥布林殺手 劇場版']" data-movie_date="03.11" data-movie_time="11:10" data-movie_title="哥布林殺手 劇場版" data-movie_type="數位" data-news="news" id="73321569" name="schedule_list" type="radio" value="2020-03-11 11:10:00"/>
# <label class="" for="73321569">11:10</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '哥布林殺手 劇場版']" data-movie_date="03.11" data-movie_time="14:40" data-movie_title="哥布林殺手 劇場版" data-movie_type="數位" data-news="news" id="73321570" name="schedule_list" type="radio" value="2020-03-11 14:40:00"/>
# <label class="" for="73321570">14:40</label>
# <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '哥布林殺手 劇場版']" data-movie_date="03.11" data-movie_time="18:10" data-movie_title="哥布林殺手 劇場版" data-movie_type="數位" data-news="news" id="73321571" name="schedule_list" type="radio" value="2020-03-11 18:10:00"/>
# <label class="" for="73321571">18:10</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="台北新光影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=35" data-theater_url="http://www.skcineplex.com.tw/" id="theater_id_35">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=35">台北新光影城</a>
# <span>02-23146668</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-cinema="cf2b5aa8132f11e6b767a1b123456789" data-date="1583856000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '哥布林殺手 劇場版']" data-movie="7af5e7a973e143f7970b14de3a39d36c" data-movie_date="03.11" data-movie_time="19:40" data-movie_title="哥布林殺手 劇場版" data-movie_type="數位" data-session="b06a244f95c346b1895f8b1527020950" data-time="1583926800" id="73288537" name="schedule_list" type="radio" value="2020-03-11 19:40:00"/>
# <label class="select" for="73288537">19:40</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="台北信義威秀影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=45" data-theater_url="http://www.vscinemas.com.tw/" id="theater_id_45">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=45">台北信義威秀影城</a>
# <span>02-87805566</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1583856000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '哥布林殺手 劇場版']" data-movie="62a62d2c5d674c20892f0e5594357100" data-movie_date="03.11" data-movie_time="18:50" data-movie_title="哥布林殺手 劇場版" data-movie_type="數位" data-session="439730263f864de4981429b7612bacc6" data-time="1583923800" id="73291719" name="schedule_list" type="radio" value="2020-03-11 18:50:00"/>
# <label class="" for="73291719">18:50</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="京站威秀影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=118" data-theater_url="http://www.vscinemas.com.tw/" id="theater_id_118">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=118">京站威秀影城</a>
# <span>02-25525511</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-cinema="5f60dacd-45b3-102d-8d74-e400529c" data-date="1583856000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '哥布林殺手 劇場版']" data-movie="a46bd88bb09149c78329f69365cb2cd0" data-movie_date="03.11" data-movie_time="18:35" data-movie_title="哥布林殺手 劇場版" data-movie_type="數位" data-session="8bc07f5dc67d4edca3e29f3a98c6c941" data-time="1583922900" id="73285249" name="schedule_list" type="radio" value="2020-03-11 18:35:00"/>
# <label class="" for="73285249">18:35</label>
# <input class="gabtn" data-cinema="5f60dacd-45b3-102d-8d74-e400529c" data-date="1583856000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '哥布林殺手 劇場版']" data-movie="a46bd88bb09149c78329f69365cb2cd0" data-movie_date="03.11" data-movie_time="20:25" data-movie_title="哥布林殺手 劇場版" data-movie_type="數位" data-session="b8a893317f1a4b4c9f27f21d6ed88a1e" data-time="1583929500" id="73285250" name="schedule_list" type="radio" value="2020-03-11 20:25:00"/>
# <label class="select" for="73285250">20:25</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="喜樂時代影城南港店" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=186" data-theater_url="http://www.centuryasia.com.tw/default.aspx" id="theater_id_186">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=186">喜樂時代影城南港店</a>
# <span>02-27888185</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1583856000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '哥布林殺手 劇場版']" data-movie="92dcbb51d1974e09be5b1b9ac062ee38" data-movie_date="03.11" data-movie_time="20:05" data-movie_title="哥布林殺手 劇場版" data-movie_type="數位" data-session="655bdd87eab84d3bb610b69a10868f37" data-time="1583928300" id="73297253" name="schedule_list" type="radio" value="2020-03-11 20:05:00"/>
# <label class="select" for="73297253">20:05</label>
# <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1583856000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '哥布林殺手 劇場版']" data-movie="92dcbb51d1974e09be5b1b9ac062ee38" data-movie_date="03.11" data-movie_time="21:45" data-movie_title="哥布林殺手 劇場版" data-movie_type="數位" data-session="50e761eb1f4f4b6dbbb5daa50a72421b" data-time="1583934300" id="73297254" name="schedule_list" type="radio" value="2020-03-11 21:45:00"/>
# <label class="select" for="73297254">21:45</label>
# </div>
# </li>
# </ul>]

# %%
'''

  試著從上一步驟回傳的電影院資料中，擷取電影院名稱、影片放映類型以及時間表
  
  Your code here.

'''
for i in html:
    print('電影院:',i.a.string)
    print('放印類型:',i.find_all('span')[-1].text)
    #print(i.find_all(("input")))
    print('放映時間:')
    for p in i.find_all(("input")):
            print('  ',p['value'])
    print('\n')
# Out:
# 電影院: 國賓影城(台北長春廣場)
# 放印類型: 數位
# 放映時間:
#    2020-03-11 11:10:00
#    2020-03-11 14:40:00
#    2020-03-11 18:10:00
#
#
# 電影院: 台北新光影城
# 放印類型: 數位
# 放映時間:
#    2020-03-11 19:40:00
#
#
# 電影院: 台北信義威秀影城
# 放印類型: 數位
# 放映時間:
#    2020-03-11 18:50:00
#
#
# 電影院: 京站威秀影城
# 放印類型: 數位
# 放映時間:
#    2020-03-11 18:35:00
#    2020-03-11 20:25:00
#
#
# 電影院: 喜樂時代影城南港店
# 放印類型: 數位
# 放映時間:
#    2020-03-11 20:05:00
#    2020-03-11 21:45:00
